# %%
import torch 
from torchvision import models, datasets
import os

# %%
current_path = os.getcwd()

# %%
path_to_dir = "/home/wannabe/Downloads/Test_datasets/Birds"

# %%
images_subfolder = path_to_dir + "/" + "images"
lists_subfolder = path_to_dir + "/" + "lists"

# %%
for directory in os.listdir(images_subfolder):
    print (file)
# Out:
# ._200.Common_Yellowthroat
# 036.Northern_Flicker
# ._037.Acadian_Flycatcher
# ._181.Worm_eating_Warbler
# ._179.Tennessee_Warbler
# 145.Elegant_Tern
# 172.Nashville_Warbler
# ._044.Frigatebird
# 157.Yellow_throated_Vireo
# ._045.Northern_Fulmar
# ._041.Scissor_tailed_Flycatcher
# ._193.Bewick_Wren
# ._177.Prothonotary_Warbler
# 012.Yellow_headed_Blackbird
# ._068.Ruby_throated_Hummingbird
# ._058.Pigeon_Guillemot
# 053.Western_Grebe
# 011.Rusty_Blackbird
# 152.Blue_headed_Vireo
# ._104.American_Pipit
# ._088.Western_Meadowlark
# 168.Kentucky_Warbler
# ._062.Herring_Gull
# 189.Red_bellied_Woodpecker
# 044.Frigatebird
# ._139.Scarlet_Tanager
# 062.Herring_Gull
# ._158.Bay_breasted_Warbler
# ._084.Red_legged_Kittiwake
# ._164.Cerulean_Warbler
# 091.Mockingbird
# 169.Magnolia_Warbler
# 122.Harris_Sparrow
# 010.Red_winged_Blackbird
# 082.Ringed_Kingfisher
# 030.Fish_Crow
# 118.House_Sparrow
# 142.Black_Tern
# ._159.Black_and_white_Warbler
# ._028.Brown_Creeper
# ._167.Hooded_Warbler
# ...

# %%
import os
from pathlib import Path

# %%
base_path = "/home/wannabe/Downloads/Test_datasets/birds"
dest_base_path = "/home/wannabe/Downloads/Test_datasets/birds/test_set"

# %%
base_path = Path(base_path)

# %%
val_split = 0.2
random_seed = 42

# %%
import numpy as np
import math

# %%
math.floor(2.5)
# Out:
# 2

# %%
files = next(os.walk(base_path))[2]

# %%
files
# Out:
# ['._200.Common_Yellowthroat',
#  '._037.Acadian_Flycatcher',
#  '._181.Worm_eating_Warbler',
#  '._179.Tennessee_Warbler',
#  '._044.Frigatebird',
#  '._045.Northern_Fulmar',
#  '._041.Scissor_tailed_Flycatcher',
#  '._193.Bewick_Wren',
#  '._177.Prothonotary_Warbler',
#  '._068.Ruby_throated_Hummingbird',
#  '._058.Pigeon_Guillemot',
#  '._104.American_Pipit',
#  '._088.Western_Meadowlark',
#  '._062.Herring_Gull',
#  '._139.Scarlet_Tanager',
#  '._158.Bay_breasted_Warbler',
#  '._084.Red_legged_Kittiwake',
#  '._164.Cerulean_Warbler',
#  '._159.Black_and_white_Warbler',
#  '._028.Brown_Creeper',
#  '._167.Hooded_Warbler',
#  '._055.Evening_Grosbeak',
#  '._052.Pied_billed_Grebe',
#  '._187.American_Three_toed_Woodpecker',
#  '._082.Ringed_Kingfisher',
#  '._160.Black_throated_Blue_Warbler',
#  '._198.Rock_Wren',
#  '._111.Loggerhead_Shrike',
#  '._094.White_breasted_Nuthatch',
#  '._097.Orchard_Oriole',
#  '._100.Brown_Pelican',
#  '._134.Cape_Glossy_Starling',
# ...

# %%
os.mkdir()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-6dd48f39a3ce> in <module>
# ----> 1 os.mkdir()
#
# TypeError: mkdir() missing required argument 'path' (pos 1)

# %%
for directory in os.listdir(base_path):
    path_to_file = os.path.join(base_path, directory)    
    if os.path.isdir(path_to_file):
        if (directory == 'train'):
            #Train directory
            for idir in os.listdir(path_to_file):
                # Images directory = working_dir
                working_dir = os.path.join(path_to_file, idir)
                #dest_dir = os.path.join()
                os.mkdir(dest_base_path + "/" + idir)
                no_of_images, images_list = len(next(os.walk(working_dir))[2]), next(os.walk(working_dir))[2]
                #indices = list(range(no_of_images))
                no_of_val_images = math.floor(val_split*no_of_images)
                for i in range(no_of_val_images):
                    shutil.move(os.path.join(working_dir,images_list[i]),dest_base_path + "/" + idir)

# %%
import shutil

# %%
path_to_dir = "/home/wannabe/TEST"
dest_base_path = "/home/wannabe/TEST2"

# %%
for idir in os.listdir(path_to_dir):
    # Images directory = working_dir
    working_dir = os.path.join(path_to_dir, idir)
    print (working_dir)
    os.mkdir(dest_base_path + "/" + idir)
    no_of_images = len(next(os.walk(working_dir))[2])  
    images_list = next(os.walk(working_dir))[2]
    #indices = list(range(no_of_images))
    no_of_val_images = math.floor(val_split*no_of_images)
    for i in range(no_of_val_images):
        shutil.move(os.path.join(working_dir,images_list[i]),dest_base_path + "/" + idir)
# Out:
# /home/wannabe/TEST/n01443537

# %%
len(next(os.walk(path_to_dir + "/" + "n01443537"))[2])
# Out:
# 500

# %%
# Out:
# PosixPath('/home/wannabe/Downloads/tiny-imagenet-200/images')
